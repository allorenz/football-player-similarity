# %%
import pandas as pd
import shap
from sklearn.ensemble import RandomForestClassifier
import sys
import os

# Add the scripts directory to the Python path to import modeling module
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), 'scripts'))

# Import the modeling module
import modeling

# Access the get_data function
# This function merges all dimensions and applies filters
# Returns two DataFrames: (absolute_values_df, relative_values_df)
df_absolute, df_relative = modeling.get_data(match_played=2, minutes_played=90)

print(f"Absolute values DataFrame shape: {df_absolute.shape}")
print(f"Relative values DataFrame shape: {df_relative.shape}")
print(f"Columns in absolute DataFrame: {list(df_absolute.columns)[:10]}...")  # Show first 10 columns
# Out:
# Dim defending shape(3069, 104)
# Dim possession shape(3069, 140)
# Dim passing shape(3069, 229)
# Dim shooting shape(3069, 206)
# Merge shape: (3069, 675)
# Apply filters: match_played=2 , minutes_player=90
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 56
#      52     print("Config 2 columns:", len(config_2_columns))
#      55     return (df_filtered.loc[:,config_1_columns].copy(), df_filtered.loc[:,config_2_columns].copy())
# ---> 56 df, _ = get_data(match_played=2, minutes_played=90)
#
# Cell In[14], line 31, in get_data(match_played, minutes_played)
#      29 # filter rows
#      30 print(f"Apply filters: match_played={match_played} , minutes_player={minutes_played}")
# ---> 31 df_filtered = filter_df(df, match_played=match_played, minutes_played=minutes_played)
#      35 # filter columns
#      36 config_1_columns = ["player_id","position"]
#
# ...
