# %%
import pandas as pd
import utils

PATH_TO_FILES = "../data/fbref/cleaned/"
dataframes = utils.get_all_attributes(PATH_TO_FILES)
datafset_names = list(dataframes.keys())
datafset_names.remove('standard_stats')
composite_key = ['Season', 'League', 'Team', 'Player', 'Nation', 'Pos', 'Age']
datafset_names
# Out:
# ['advanced_goalkeeping',
#  'defensive_actions',
#  'goalkeeping',
#  'goal_and_shot_creation',
#  'miscellaneous_stats',
#  'passing',
#  'playing_time',
#  'possession',
#  'shooting']

# %% [markdown]
# ### Create composite id to overcome none-unique player names
# This can be due to transfer during winter period or similar names

# %%
df = dataframes['standard_stats']
df['unique_id'] = df['Player'] + '_' + df['Season'] + '_' + df['League'] + '_' + df['Team']
df.set_index('unique_id',inplace=True)
df.shape
# Out:
# (5071, 36)

# %% [markdown]
# ### Define which columns to keep

# %%
def_cols = ['Tackles_Att', 'Tackles_Def 3rd', 'Tackles_Mid 3rd',
        'Tackles_Att 3rd','Interceptions', 'Clearances','Errors',
        'Dribblers_Tkl_Succ','Dribblers_Tkl_Att','Dribblers_Tkl_Lost',
        'Blocks_Total', 'Blocks_Shots',
        ]

misc_cols = ['2CrdY', 'Fls', 'Fld', 'Off', 'Crs','PKwon', 
            'PKcon', 'OG', 'Recov', 'Aerial Duels_Won',
            'Aerial Duels_Lost'
        ]

passing_cols = ['Total_Cmp', 'Total_Att', 'Total_Cmp%', 'Total_TotDist',
       'Total_PrgDist','Short_Cmp', 'Short_Att', 'Short_Cmp%', 'Medium_Cmp',
       'Medium_Att', 'Medium_Cmp%', 'Long_Cmp', 'Long_Att', 'Long_Cmp%','Assists', 'Key Passes', 'Passes_to_1/3',
       'Passes_to_Penalt_Area', 'Crosses_into_Penalty_Area','Progressive Passes']

playing_time_cols = ['Playing Time_Minutes', 'Playing Time_Mn/MP','Starts', 'Mn/Start', 'Compl',
                     'Subs', 'unSub', 'PPM','onG', 'onGA','On-Off'
                    ]

possession_cols = ['Touches_Number', 'Touches_Def Pen', 'Touches_Def 3rd',
       'Touches_Mid 3rd', 'Touches_Att 3rd', 'Touches_Att Pen','Take-Ons_Att', 'Take-Ons_Succ',
       'Take-Ons_Tkld','Take-Ons_Tkld%','Carries_Number', 'Carries_TotDist',
       'Carries_PrgDist', 'Carries_PrgC', 'Carries_1/3', 'Carries_CPA',
       'Carries_Mis', 'Carries_Dis','Receiving_Succ', 'Receiving_PrgR'
        ]

shooting_cols = ['Goals', 'Shots', 'SoT', 'SoT%', 'Shots/90','Goals/Shot', 'Goals/SoT']

gsc_cols = ['SCA', 'SCA90', 'SCA Types_PassLive', 'SCA Types_PassDead',
       'SCA Types_TO', 'SCA Types_Sh', 'SCA Types_Fld', 'SCA Types_Def', 'GCA',
       'GCA90', 'GCA Types_PassLive', 'GCA Types_PassDead', 'GCA Types_TO',
       'GCA Types_Sh', 'GCA Types_Fld', 'GCA Types_Def'
        ]
adv_goalkeeping = ['Goals_GA', 'Goals_PKA', 'Goals_FK', 'Goals_CK', 'Goals_OG', 'PSxG',
       'PSxG/SoT', 'PSxG+/-', '/90', 'Launched_Cmp', 'Launched_Att',
       'Launched_Cmp%', 'Passes_Att', 'Passes_Thr', 'Passes_Launch%',
       'Passes_AvgLen', 'Goal Kicks_Att', 'Goal Kicks_Launch%',
       'Goal Kicks_AvgLen', 'Opp', 'Stp', 'Stp%', '#OPA', '#OPA/90',
       'AvgDist']
goalkeeping_cols = ['GA',
       'GA90', 'SoTA', 'Saves', 'Save%', 'W', 'D', 'L', 'CS', 'CS%',
       'Penalty Kicks_PKatt', 'Penalty Kicks_PKA', 'Penalty Kicks_PKsv',
       'Penalty Kicks_PKm', 'Penalty Kicks_Save%']

dic_col_to_keep = {
    'defensive_actions': def_cols,
    'goal_and_shot_creation' : gsc_cols,
    'miscellaneous_stats': misc_cols,
    'passing' : passing_cols,
    'playing_time' : playing_time_cols,
    'possession' : possession_cols,
    'shooting' : shooting_cols,
    'advanced_goalkeeping' : adv_goalkeeping,
    'goalkeeping':goalkeeping_cols
}

# %% [markdown]
# ### Define the renaming of certain columns

# %%
rename_def = { 'Tackles_Tkl': 'Tackles_Att',
           'Challenges_Tkl': 'Dribblers_Tkl_Succ',
           'Challenges_Att': 'Dribblers_Tkl_Att',
           'Challenges_Lost': 'Dribblers_Tkl_Lost',
           'Blocks_Blocks': 'Blocks_Total',
           'Blocks_Sh': 'Blocks_Shots',
          }

rename_gsc = {'SCA_SCA': 'SCA',
          'SCA_SCA90' : 'SCA90',
          'GCA_GCA':'GCA',
          'GCA_GCA90': 'GCA90'
          }
rename_misc = {}
rename_passing = {}
rename_playing_time = {'Playing Time_Min': 'Playing Time_Minutes'
          }

rename_possession = {'Touches_Touches': 'Touches_Number',
          'Carries_Carries': 'Carries_Number',
          'Receiving_Rec': 'Receiving_Succ'}

rename_shooting = {'Gls': 'Goals',
          'Sh': 'Shots',
          'Sh/90': 'Shots/90',
          'G/Sh': 'Goals/Shot',
          'G/SoT': 'Goals/SoT'
          }
rename_advgoal = {}
rename_goalkeeping = {}
dic_col_to_rename = {
    'defensive_actions': rename_def,
    'goal_and_shot_creation' : rename_gsc,
    'miscellaneous_stats': rename_misc,
    'passing' : rename_passing,
    'playing_time' : rename_playing_time,
    'possession' : rename_possession,
    'shooting' : rename_shooting,
    'advanced_goalkeeping' : rename_advgoal,
    'goalkeeping': rename_goalkeeping
}

# %% [markdown]
# ### Merge all dataframes

# %%
for name in datafset_names:
    df_temp = dataframes[name]
    df_temp['unique_id'] = df_temp['Player'] + '_' + df_temp['Season'] + '_' + df_temp['League'] + '_' + df_temp['Team']
    df_temp.set_index('unique_id',inplace=True)
    
    columns_to_rename = dic_col_to_rename[name]
    df_temp = df_temp.rename(columns=columns_to_rename)

    columns_to_keep = dic_col_to_keep[name]
    df_temp = df_temp[columns_to_keep]

    df = df.join(df_temp)

# %%
df
# Out:
#                                                        Season        League  \
# unique_id
# Ederson_2022-2023_EPL_Manchester City               2022-2023           EPL
# Rodri_2022-2023_EPL_Manchester City                 2022-2023           EPL
# Erling Haaland_2022-2023_EPL_Manchester City        2022-2023           EPL
# Kevin De Bruyne_2022-2023_EPL_Manchester City       2022-2023           EPL
# İlkay Gündoğan_2022-2023_EPL_Manchester City        2022-2023           EPL
# ...                                                       ...           ...
# João Afonso_2022-2023_PrimeiraLiga_Santa Clara      2022-2023  PrimeiraLiga
# Marcos Guillermo Díaz_2022-2023_PrimeiraLiga_Sa...  2022-2023  PrimeiraLiga
# Ricardo Manuel Silva_2022-2023_PrimeiraLiga_San...  2022-2023  PrimeiraLiga
# Squad Total_2022-2023_PrimeiraLiga_Santa Clara      2022-2023  PrimeiraLiga
# Opponent Total_2022-2023_PrimeiraLiga_Santa Clara   2022-2023  PrimeiraLiga
#
#                                                                Team  \
# unique_id
# Ederson_2022-2023_EPL_Manchester City               Manchester City
# Rodri_2022-2023_EPL_Manchester City                 Manchester City
# Erling Haaland_2022-2023_EPL_Manchester City        Manchester City
# Kevin De Bruyne_2022-2023_EPL_Manchester City       Manchester City
# İlkay Gündoğan_2022-2023_EPL_Manchester City        Manchester City
# ...                                                             ...
# João Afonso_2022-2023_PrimeiraLiga_Santa Clara          Santa Clara
# Marcos Guillermo Díaz_2022-2023_PrimeiraLiga_Sa...      Santa Clara
# Ricardo Manuel Silva_2022-2023_PrimeiraLiga_San...      Santa Clara
# Squad Total_2022-2023_PrimeiraLiga_Santa Clara          Santa Clara
# Opponent Total_2022-2023_PrimeiraLiga_Santa Clara       Santa Clara
#
#                                                                    Player  \
# unique_id
# Ederson_2022-2023_EPL_Manchester City                             Ederson
# Rodri_2022-2023_EPL_Manchester City                                 Rodri
# Erling Haaland_2022-2023_EPL_Manchester City               Erling Haaland
# Kevin De Bruyne_2022-2023_EPL_Manchester City             Kevin De Bruyne
# İlkay Gündoğan_2022-2023_EPL_Manchester City               İlkay Gündoğan
# ...                                                                   ...
# João Afonso_2022-2023_PrimeiraLiga_Santa Clara                João Afonso
# Marcos Guillermo Díaz_2022-2023_PrimeiraLiga_Sa...  Marcos Guillermo Díaz
# Ricardo Manuel Silva_2022-2023_PrimeiraLiga_San...   Ricardo Manuel Silva
# Squad Total_2022-2023_PrimeiraLiga_Santa Clara                Squad Total
# Opponent Total_2022-2023_PrimeiraLiga_Santa Clara          Opponent Total
#
#                                                    Nation  Pos   Age  \
# unique_id
# Ederson_2022-2023_EPL_Manchester City                 BRA   GK  28.0
# Rodri_2022-2023_EPL_Manchester City                   ESP   MF  26.0
# Erling Haaland_2022-2023_EPL_Manchester City          NOR   FW  22.0
# Kevin De Bruyne_2022-2023_EPL_Manchester City         BEL   MF  31.0
# İlkay Gündoğan_2022-2023_EPL_Manchester City          GER   MF  31.0
# ...                                                   ...  ...   ...
# João Afonso_2022-2023_PrimeiraLiga_Santa Clara        POR   DF  32.0
# Marcos Guillermo Díaz_2022-2023_PrimeiraLiga_Sa...    ARG   GK  36.0
# Ricardo Manuel Silva_2022-2023_PrimeiraLiga_San...    POR   GK  23.0
# Squad Total_2022-2023_PrimeiraLiga_Santa Clara        NaN  NaN  25.0
# Opponent Total_2022-2023_PrimeiraLiga_Santa Clara     NaN  NaN  26.2
#
#                                                     Playing Time_Starts  \
# unique_id
# Ederson_2022-2023_EPL_Manchester City                              35.0
# Rodri_2022-2023_EPL_Manchester City                                34.0
# Erling Haaland_2022-2023_EPL_Manchester City                       33.0
# Kevin De Bruyne_2022-2023_EPL_Manchester City                      28.0
# İlkay Gündoğan_2022-2023_EPL_Manchester City                       27.0
# ...                                                                 ...
# João Afonso_2022-2023_PrimeiraLiga_Santa Clara                      0.0
# Marcos Guillermo Díaz_2022-2023_PrimeiraLiga_Sa...                  0.0
# Ricardo Manuel Silva_2022-2023_PrimeiraLiga_San...                  0.0
# Squad Total_2022-2023_PrimeiraLiga_Santa Clara                    374.0
# Opponent Total_2022-2023_PrimeiraLiga_Santa Clara                 374.0
#
#                                                     Playing Time_Min  \
# unique_id
# Ederson_2022-2023_EPL_Manchester City                         3150.0
# Rodri_2022-2023_EPL_Manchester City                           2911.0
# Erling Haaland_2022-2023_EPL_Manchester City                  2769.0
# Kevin De Bruyne_2022-2023_EPL_Manchester City                 2417.0
# İlkay Gündoğan_2022-2023_EPL_Manchester City                  2353.0
# ...                                                              ...
# João Afonso_2022-2023_PrimeiraLiga_Santa Clara                   NaN
# Marcos Guillermo Díaz_2022-2023_PrimeiraLiga_Sa...               NaN
# Ricardo Manuel Silva_2022-2023_PrimeiraLiga_San...               NaN
# Squad Total_2022-2023_PrimeiraLiga_Santa Clara                3060.0
# Opponent Total_2022-2023_PrimeiraLiga_Santa Clara             3060.0
#
#                                                     Playing Time_90s  ...  \
# unique_id                                                             ...
# Ederson_2022-2023_EPL_Manchester City                           35.0  ...
# Rodri_2022-2023_EPL_Manchester City                             32.3  ...
# Erling Haaland_2022-2023_EPL_Manchester City                    30.8  ...
# Kevin De Bruyne_2022-2023_EPL_Manchester City                   26.9  ...
# İlkay Gündoğan_2022-2023_EPL_Manchester City                    26.1  ...
# ...                                                              ...  ...
# João Afonso_2022-2023_PrimeiraLiga_Santa Clara                   NaN  ...
# Marcos Guillermo Díaz_2022-2023_PrimeiraLiga_Sa...               NaN  ...
# Ricardo Manuel Silva_2022-2023_PrimeiraLiga_San...               NaN  ...
# Squad Total_2022-2023_PrimeiraLiga_Santa Clara                  34.0  ...
# Opponent Total_2022-2023_PrimeiraLiga_Santa Clara               34.0  ...
#
#                                                     Carries_Dis  \
# unique_id
# Ederson_2022-2023_EPL_Manchester City                       0.0
# Rodri_2022-2023_EPL_Manchester City                        19.0
# Erling Haaland_2022-2023_EPL_Manchester City               26.0
# Kevin De Bruyne_2022-2023_EPL_Manchester City              29.0
# İlkay Gündoğan_2022-2023_EPL_Manchester City               27.0
# ...                                                         ...
# João Afonso_2022-2023_PrimeiraLiga_Santa Clara              NaN
# Marcos Guillermo Díaz_2022-2023_PrimeiraLiga_Sa...          NaN
# Ricardo Manuel Silva_2022-2023_PrimeiraLiga_San...          NaN
# Squad Total_2022-2023_PrimeiraLiga_Santa Clara            273.0
# Opponent Total_2022-2023_PrimeiraLiga_Santa Clara         272.0
#
#                                                     Receiving_Succ  \
# unique_id
# Ederson_2022-2023_EPL_Manchester City                        833.0
# Rodri_2022-2023_EPL_Manchester City                         2511.0
# Erling Haaland_2022-2023_EPL_Manchester City                 583.0
# Kevin De Bruyne_2022-2023_EPL_Manchester City               1445.0
# İlkay Gündoğan_2022-2023_EPL_Manchester City                1425.0
# ...                                                            ...
# João Afonso_2022-2023_PrimeiraLiga_Santa Clara                 NaN
# Marcos Guillermo Díaz_2022-2023_PrimeiraLiga_Sa...             NaN
# Ricardo Manuel Silva_2022-2023_PrimeiraLiga_San...             NaN
# Squad Total_2022-2023_PrimeiraLiga_Santa Clara              9214.0
# Opponent Total_2022-2023_PrimeiraLiga_Santa Clara          13993.0
#
#                                                     Receiving_PrgR  Goals  \
# unique_id
# Ederson_2022-2023_EPL_Manchester City                          0.0    0.0
# Rodri_2022-2023_EPL_Manchester City                           37.0    2.0
# Erling Haaland_2022-2023_EPL_Manchester City                 151.0   36.0
# Kevin De Bruyne_2022-2023_EPL_Manchester City                245.0    7.0
# İlkay Gündoğan_2022-2023_EPL_Manchester City                 124.0    8.0
# ...                                                            ...    ...
# João Afonso_2022-2023_PrimeiraLiga_Santa Clara                 NaN    NaN
# Marcos Guillermo Díaz_2022-2023_PrimeiraLiga_Sa...             NaN    NaN
# Ricardo Manuel Silva_2022-2023_PrimeiraLiga_San...             NaN    NaN
# Squad Total_2022-2023_PrimeiraLiga_Santa Clara               908.0   26.0
# Opponent Total_2022-2023_PrimeiraLiga_Santa Clara           1344.0   55.0
#
#                                                     Shots    SoT  SoT%  \
# unique_id
# Ederson_2022-2023_EPL_Manchester City                 0.0    0.0   NaN
# Rodri_2022-2023_EPL_Manchester City                  50.0   14.0  28.0
# Erling Haaland_2022-2023_EPL_Manchester City        116.0   53.0  45.7
# Kevin De Bruyne_2022-2023_EPL_Manchester City        65.0   21.0  32.3
# İlkay Gündoğan_2022-2023_EPL_Manchester City         53.0   20.0  37.7
# ...                                                   ...    ...   ...
# João Afonso_2022-2023_PrimeiraLiga_Santa Clara        NaN    NaN   NaN
# Marcos Guillermo Díaz_2022-2023_PrimeiraLiga_Sa...    NaN    NaN   NaN
# Ricardo Manuel Silva_2022-2023_PrimeiraLiga_San...    NaN    NaN   NaN
# Squad Total_2022-2023_PrimeiraLiga_Santa Clara      353.0  111.0  31.4
# Opponent Total_2022-2023_PrimeiraLiga_Santa Clara   446.0  151.0  33.9
#
#                                                     Shots/90  Goals/Shot  \
# unique_id
# Ederson_2022-2023_EPL_Manchester City                   0.00         NaN
# Rodri_2022-2023_EPL_Manchester City                     1.55        0.04
# Erling Haaland_2022-2023_EPL_Manchester City            3.77        0.25
# Kevin De Bruyne_2022-2023_EPL_Manchester City           2.42        0.11
# İlkay Gündoğan_2022-2023_EPL_Manchester City            2.03        0.15
# ...                                                      ...         ...
# João Afonso_2022-2023_PrimeiraLiga_Santa Clara           NaN         NaN
# Marcos Guillermo Díaz_2022-2023_PrimeiraLiga_Sa...       NaN         NaN
# Ricardo Manuel Silva_2022-2023_PrimeiraLiga_San...       NaN         NaN
# Squad Total_2022-2023_PrimeiraLiga_Santa Clara         10.38        0.06
# Opponent Total_2022-2023_PrimeiraLiga_Santa Clara      13.12        0.11
#
#                                                     Goals/SoT
# unique_id
# Ederson_2022-2023_EPL_Manchester City                     NaN
# Rodri_2022-2023_EPL_Manchester City                      0.14
# Erling Haaland_2022-2023_EPL_Manchester City             0.55
# Kevin De Bruyne_2022-2023_EPL_Manchester City            0.33
# İlkay Gündoğan_2022-2023_EPL_Manchester City             0.40
# ...                                                       ...
# João Afonso_2022-2023_PrimeiraLiga_Santa Clara            NaN
# Marcos Guillermo Díaz_2022-2023_PrimeiraLiga_Sa...        NaN
# Ricardo Manuel Silva_2022-2023_PrimeiraLiga_San...        NaN
# Squad Total_2022-2023_PrimeiraLiga_Santa Clara           0.18
# Opponent Total_2022-2023_PrimeiraLiga_Santa Clara        0.32
#
# [5071 rows x 173 columns]

# %% [markdown]
# ### Assign Global Positions

# %%
def map_position(pos):
    glob_pos_dic = {
    'DF' : ['DF,MF', 'DF,FW'],
    'MF': ['MF,DF', 'MF,FW'],
    'FW': ['FW,MF', 'FW,DF']}

    for key, value_list in glob_pos_dic.items():
        if pos in value_list:
            return key
    return pos

df['Global Pos'] = df['Pos'].apply(map_position)

# %%
t = ['Season', 'League', 'Team', 'Player', 'Nation', 'Pos', 'Age','Matches Played','Goals']
#df.loc[:,['Matches Played']]
df[t]
# Out:
#                                                        Season        League  \
# unique_id
# Ederson_2022-2023_EPL_Manchester City               2022-2023           EPL
# Rodri_2022-2023_EPL_Manchester City                 2022-2023           EPL
# Erling Haaland_2022-2023_EPL_Manchester City        2022-2023           EPL
# Kevin De Bruyne_2022-2023_EPL_Manchester City       2022-2023           EPL
# İlkay Gündoğan_2022-2023_EPL_Manchester City        2022-2023           EPL
# ...                                                       ...           ...
# João Afonso_2022-2023_PrimeiraLiga_Santa Clara      2022-2023  PrimeiraLiga
# Marcos Guillermo Díaz_2022-2023_PrimeiraLiga_Sa...  2022-2023  PrimeiraLiga
# Ricardo Manuel Silva_2022-2023_PrimeiraLiga_San...  2022-2023  PrimeiraLiga
# Squad Total_2022-2023_PrimeiraLiga_Santa Clara      2022-2023  PrimeiraLiga
# Opponent Total_2022-2023_PrimeiraLiga_Santa Clara   2022-2023  PrimeiraLiga
#
#                                                                Team  \
# unique_id
# Ederson_2022-2023_EPL_Manchester City               Manchester City
# Rodri_2022-2023_EPL_Manchester City                 Manchester City
# Erling Haaland_2022-2023_EPL_Manchester City        Manchester City
# Kevin De Bruyne_2022-2023_EPL_Manchester City       Manchester City
# İlkay Gündoğan_2022-2023_EPL_Manchester City        Manchester City
# ...                                                             ...
# João Afonso_2022-2023_PrimeiraLiga_Santa Clara          Santa Clara
# Marcos Guillermo Díaz_2022-2023_PrimeiraLiga_Sa...      Santa Clara
# Ricardo Manuel Silva_2022-2023_PrimeiraLiga_San...      Santa Clara
# Squad Total_2022-2023_PrimeiraLiga_Santa Clara          Santa Clara
# Opponent Total_2022-2023_PrimeiraLiga_Santa Clara       Santa Clara
#
#                                                                    Player  \
# unique_id
# Ederson_2022-2023_EPL_Manchester City                             Ederson
# Rodri_2022-2023_EPL_Manchester City                                 Rodri
# Erling Haaland_2022-2023_EPL_Manchester City               Erling Haaland
# Kevin De Bruyne_2022-2023_EPL_Manchester City             Kevin De Bruyne
# İlkay Gündoğan_2022-2023_EPL_Manchester City               İlkay Gündoğan
# ...                                                                   ...
# João Afonso_2022-2023_PrimeiraLiga_Santa Clara                João Afonso
# Marcos Guillermo Díaz_2022-2023_PrimeiraLiga_Sa...  Marcos Guillermo Díaz
# Ricardo Manuel Silva_2022-2023_PrimeiraLiga_San...   Ricardo Manuel Silva
# Squad Total_2022-2023_PrimeiraLiga_Santa Clara                Squad Total
# Opponent Total_2022-2023_PrimeiraLiga_Santa Clara          Opponent Total
#
#                                                    Nation  Pos   Age  \
# unique_id
# Ederson_2022-2023_EPL_Manchester City                 BRA   GK  28.0
# Rodri_2022-2023_EPL_Manchester City                   ESP   MF  26.0
# Erling Haaland_2022-2023_EPL_Manchester City          NOR   FW  22.0
# Kevin De Bruyne_2022-2023_EPL_Manchester City         BEL   MF  31.0
# İlkay Gündoğan_2022-2023_EPL_Manchester City          GER   MF  31.0
# ...                                                   ...  ...   ...
# João Afonso_2022-2023_PrimeiraLiga_Santa Clara        POR   DF  32.0
# Marcos Guillermo Díaz_2022-2023_PrimeiraLiga_Sa...    ARG   GK  36.0
# Ricardo Manuel Silva_2022-2023_PrimeiraLiga_San...    POR   GK  23.0
# Squad Total_2022-2023_PrimeiraLiga_Santa Clara        NaN  NaN  25.0
# Opponent Total_2022-2023_PrimeiraLiga_Santa Clara     NaN  NaN  26.2
#
#                                                     Matches Played  Goals
# unique_id
# Ederson_2022-2023_EPL_Manchester City                         35.0    0.0
# Rodri_2022-2023_EPL_Manchester City                           36.0    2.0
# Erling Haaland_2022-2023_EPL_Manchester City                  35.0   36.0
# Kevin De Bruyne_2022-2023_EPL_Manchester City                 32.0    7.0
# İlkay Gündoğan_2022-2023_EPL_Manchester City                  31.0    8.0
# ...                                                            ...    ...
# João Afonso_2022-2023_PrimeiraLiga_Santa Clara                 0.0    NaN
# Marcos Guillermo Díaz_2022-2023_PrimeiraLiga_Sa...             0.0    NaN
# Ricardo Manuel Silva_2022-2023_PrimeiraLiga_San...             0.0    NaN
# Squad Total_2022-2023_PrimeiraLiga_Santa Clara                34.0   26.0
# Opponent Total_2022-2023_PrimeiraLiga_Santa Clara             34.0   55.0
#
# [5071 rows x 9 columns]

# %% [markdown]
# ### Arrange feature space

# %%
for c in df.columns:
    print(c)
# Out:
# Season
# League
# Team
# Player
# Nation
# Pos
# Age
# Playing Time_Starts
# Playing Time_Min
# Playing Time_90s
# Gls
# Ast
# G+A
# G-PK
# PK
# PKatt
# CrdY
# CrdR
# PrgC
# PrgP
# PrgR
# Per 90 Minutes_Gls
# Per 90 Minutes_Ast
# Per 90 Minutes_G+A
# Per 90 Minutes_G-PK
# Per 90 Minutes_G+A-PK
# xG
# npxG
# xAG
# npxG+xAG
# Per 90 Minutes_xG
# Per 90 Minutes_xAG
# Per 90 Minutes_xG+xAG
# Per 90 Minutes_npxG
# Per 90 Minutes_npxG+xAG
# Matches Played
# Goals_GA
# Goals_PKA
# Goals_FK
# Goals_CK
# Goals_OG
# PSxG
# PSxG/SoT
# PSxG+/-
# /90
# Launched_Cmp
# Launched_Att
# Launched_Cmp%
# Passes_Att
# Passes_Thr
# Passes_Launch%
# Passes_AvgLen
# Goal Kicks_Att
# Goal Kicks_Launch%
# Goal Kicks_AvgLen
# Opp
# Stp
# Stp%
# #OPA
# #OPA/90
# AvgDist
# Tackles_Att
# Tackles_Def 3rd
# Tackles_Mid 3rd
# Tackles_Att 3rd
# Interceptions
# Clearances
# Errors
# Dribblers_Tkl_Succ
# Dribblers_Tkl_Att
# Dribblers_Tkl_Lost
# Blocks_Total
# Blocks_Shots
# GA
# GA90
# SoTA
# Saves
# Save%
# W
# D
# L
# CS
# CS%
# Penalty Kicks_PKatt
# Penalty Kicks_PKA
# Penalty Kicks_PKsv
# Penalty Kicks_PKm
# Penalty Kicks_Save%
# SCA
# SCA90
# SCA Types_PassLive
# SCA Types_PassDead
# SCA Types_TO
# SCA Types_Sh
# SCA Types_Fld
# SCA Types_Def
# GCA
# GCA90
# GCA Types_PassLive
# GCA Types_PassDead
# GCA Types_TO
# GCA Types_Sh
# GCA Types_Fld
# GCA Types_Def
# 2CrdY
# Fls
# Fld
# Off
# Crs
# PKwon
# PKcon
# OG
# Recov
# Aerial Duels_Won
# Aerial Duels_Lost
# Total_Cmp
# Total_Att
# Total_Cmp%
# Total_TotDist
# Total_PrgDist
# Short_Cmp
# Short_Att
# Short_Cmp%
# Medium_Cmp
# Medium_Att
# Medium_Cmp%
# Long_Cmp
# Long_Att
# Long_Cmp%
# Assists
# Key Passes
# Passes_to_1/3
# Passes_to_Penalt_Area
# Crosses_into_Penalty_Area
# Progressive Passes
# Playing Time_Minutes
# Playing Time_Mn/MP
# Starts
# Mn/Start
# Compl
# Subs
# unSub
# PPM
# onG
# onGA
# On-Off
# Touches_Number
# Touches_Def Pen
# Touches_Def 3rd
# Touches_Mid 3rd
# Touches_Att 3rd
# Touches_Att Pen
# Take-Ons_Att
# Take-Ons_Succ
# Take-Ons_Tkld
# Take-Ons_Tkld%
# Carries_Number
# Carries_TotDist
# Carries_PrgDist
# Carries_PrgC
# Carries_1/3
# Carries_CPA
# Carries_Mis
# Carries_Dis
# Receiving_Succ
# Receiving_PrgR
# Goals
# Shots
# SoT
# SoT%
# Shots/90
# Goals/Shot
# Goals/SoT
# Global Pos

# %%
dataframes['standard_stats'].columns
# Out:
# Index(['Season', 'League', 'Team', 'Player', 'Nation', 'Pos', 'Age',
#        'Playing Time_Starts', 'Playing Time_Min', 'Playing Time_90s', 'Gls',
#        'Ast', 'G+A', 'G-PK', 'PK', 'PKatt', 'CrdY', 'CrdR', 'PrgC', 'PrgP',
#        'PrgR', 'Per 90 Minutes_Gls', 'Per 90 Minutes_Ast',
#        'Per 90 Minutes_G+A', 'Per 90 Minutes_G-PK', 'Per 90 Minutes_G+A-PK',
#        'xG', 'npxG', 'xAG', 'npxG+xAG', 'Per 90 Minutes_xG',
#        'Per 90 Minutes_xAG', 'Per 90 Minutes_xG+xAG', 'Per 90 Minutes_npxG',
#        'Per 90 Minutes_npxG+xAG', 'Matches Played'],
#       dtype='object')

# %%
player_info_cols = ['Season', 'League', 'Team', 'Player', 'Nation', 'Pos','Global Pos', 'Age','Matches Played','Playing Time_Starts','Playing Time_Min','Playing Time_90s']

def_cols = ['Tackles_Att', 'Tackles_Def 3rd', 'Tackles_Mid 3rd',
        'Tackles_Att 3rd','Interceptions', 'Clearances','Errors',
        'Dribblers_Tkl_Succ','Dribblers_Tkl_Att','Dribblers_Tkl_Lost',
        'Blocks_Total', 'Blocks_Shots',
        ]

possession_cols = ['Touches_Number', 'Touches_Def Pen', 'Touches_Def 3rd',
       'Touches_Mid 3rd', 'Touches_Att 3rd', 'Touches_Att Pen','Take-Ons_Att', 'Take-Ons_Succ',
       'Take-Ons_Tkld','Take-Ons_Tkld%','Carries_Number', 'Carries_TotDist',
       'Carries_PrgDist', 'Carries_PrgC', 'Carries_1/3', 'Carries_CPA',
       'Carries_Mis', 'Carries_Dis','Receiving_Succ', 'Receiving_PrgR'
        ]
passing_cols = ['Total_Cmp', 'Total_Att', 'Total_Cmp%', 'Total_TotDist',
       'Total_PrgDist','Short_Cmp', 'Short_Att', 'Short_Cmp%', 'Medium_Cmp',
       'Medium_Att', 'Medium_Cmp%', 'Long_Cmp', 'Long_Att', 'Long_Cmp%','Assists', 'Key Passes', 'Passes_to_1/3',
       'Passes_to_Penalt_Area', 'Crosses_into_Penalty_Area','Progressive Passes']

gsc_cols = ['SCA', 'SCA90', 'SCA Types_PassLive', 'SCA Types_PassDead',
       'SCA Types_TO', 'SCA Types_Sh', 'SCA Types_Fld', 'SCA Types_Def', 'GCA',
       'GCA90', 'GCA Types_PassLive', 'GCA Types_PassDead', 'GCA Types_TO',
       'GCA Types_Sh', 'GCA Types_Fld', 'GCA Types_Def'
        ]

shooting_cols = ['Goals', 'Shots', 'SoT', 'SoT%', 'Shots/90','Goals/Shot', 'Goals/SoT']

adv_goalkeeping = ['Goals_GA', 'Goals_PKA', 'Goals_FK', 'Goals_CK', 'Goals_OG', 'PSxG',
       'PSxG/SoT', 'PSxG+/-', '/90', 'Launched_Cmp', 'Launched_Att',
       'Launched_Cmp%', 'Passes_Att', 'Passes_Thr', 'Passes_Launch%',
       'Passes_AvgLen', 'Goal Kicks_Att', 'Goal Kicks_Launch%',
       'Goal Kicks_AvgLen', 'Opp', 'Stp', 'Stp%', '#OPA', '#OPA/90',
       'AvgDist']
goalkeeping_cols = ['GA',
       'GA90', 'SoTA', 'Saves', 'Save%', 'W', 'D', 'L', 'CS', 'CS%',
       'Penalty Kicks_PKatt', 'Penalty Kicks_PKA', 'Penalty Kicks_PKsv',
       'Penalty Kicks_PKm', 'Penalty Kicks_Save%']


misc_cols = ['2CrdY', 'Fls', 'Fld', 'Off', 'Crs','PKwon', 
            'PKcon', 'OG', 'Recov', 'Aerial Duels_Won',
            'Aerial Duels_Lost'
        ]



playing_time_cols = ['Playing Time_Minutes', 'Playing Time_Mn/MP','Starts', 'Mn/Start', 'Compl',
                     'Subs', 'unSub', 'PPM','onG', 'onGA','On-Off'
                    ]

feature_vector = (player_info_cols + def_cols + possession_cols + passing_cols + 
               gsc_cols + shooting_cols + adv_goalkeeping + goalkeeping_cols + 
               misc_cols + playing_time_cols)


df = df[feature_vector]

# %% [markdown]
# ### Find possession indeces in df

# %%
start_idx = df.columns.get_loc(possession_cols[0])
end_idx = df.columns.get_loc(possession_cols[-1])
print(f"The 'playing_time_cols' are located from index {start_idx} to {end_idx} in df")
df.shape
# Out:
# The 'playing_time_cols' are located from index 24 to 43 in df
# (5071, 149)

# %% [markdown]
# ### Store dataset

# %%
df.head()
# Out:
#                                                   Season League  \
# unique_id
# Ederson_2022-2023_EPL_Manchester City          2022-2023    EPL
# Rodri_2022-2023_EPL_Manchester City            2022-2023    EPL
# Erling Haaland_2022-2023_EPL_Manchester City   2022-2023    EPL
# Kevin De Bruyne_2022-2023_EPL_Manchester City  2022-2023    EPL
# İlkay Gündoğan_2022-2023_EPL_Manchester City   2022-2023    EPL
#
#                                                           Team  \
# unique_id
# Ederson_2022-2023_EPL_Manchester City          Manchester City
# Rodri_2022-2023_EPL_Manchester City            Manchester City
# Erling Haaland_2022-2023_EPL_Manchester City   Manchester City
# Kevin De Bruyne_2022-2023_EPL_Manchester City  Manchester City
# İlkay Gündoğan_2022-2023_EPL_Manchester City   Manchester City
#
#                                                         Player Nation Pos  \
# unique_id
# Ederson_2022-2023_EPL_Manchester City                  Ederson    BRA  GK
# Rodri_2022-2023_EPL_Manchester City                      Rodri    ESP  MF
# Erling Haaland_2022-2023_EPL_Manchester City    Erling Haaland    NOR  FW
# Kevin De Bruyne_2022-2023_EPL_Manchester City  Kevin De Bruyne    BEL  MF
# İlkay Gündoğan_2022-2023_EPL_Manchester City    İlkay Gündoğan    GER  MF
#
#                                               Global Pos   Age  \
# unique_id
# Ederson_2022-2023_EPL_Manchester City                 GK  28.0
# Rodri_2022-2023_EPL_Manchester City                   MF  26.0
# Erling Haaland_2022-2023_EPL_Manchester City          FW  22.0
# Kevin De Bruyne_2022-2023_EPL_Manchester City         MF  31.0
# İlkay Gündoğan_2022-2023_EPL_Manchester City          MF  31.0
#
#                                                Matches Played  \
# unique_id
# Ederson_2022-2023_EPL_Manchester City                    35.0
# Rodri_2022-2023_EPL_Manchester City                      36.0
# Erling Haaland_2022-2023_EPL_Manchester City             35.0
# Kevin De Bruyne_2022-2023_EPL_Manchester City            32.0
# İlkay Gündoğan_2022-2023_EPL_Manchester City             31.0
#
#                                                Playing Time_Starts  ...  \
# unique_id                                                           ...
# Ederson_2022-2023_EPL_Manchester City                         35.0  ...
# Rodri_2022-2023_EPL_Manchester City                           34.0  ...
# Erling Haaland_2022-2023_EPL_Manchester City                  33.0  ...
# Kevin De Bruyne_2022-2023_EPL_Manchester City                 28.0  ...
# İlkay Gündoğan_2022-2023_EPL_Manchester City                  27.0  ...
#
#                                                Playing Time_Mn/MP  Starts  \
# unique_id
# Ederson_2022-2023_EPL_Manchester City                        90.0    35.0
# Rodri_2022-2023_EPL_Manchester City                          81.0    34.0
# Erling Haaland_2022-2023_EPL_Manchester City                 79.0    33.0
# Kevin De Bruyne_2022-2023_EPL_Manchester City                76.0    28.0
# İlkay Gündoğan_2022-2023_EPL_Manchester City                 76.0    27.0
#
#                                                Mn/Start  Compl  Subs  unSub  \
# unique_id
# Ederson_2022-2023_EPL_Manchester City              90.0   35.0   0.0    3.0
# Rodri_2022-2023_EPL_Manchester City                85.0   23.0   2.0    1.0
# Erling Haaland_2022-2023_EPL_Manchester City       83.0   21.0   2.0    1.0
# Kevin De Bruyne_2022-2023_EPL_Manchester City      84.0   16.0   4.0    3.0
# İlkay Gündoğan_2022-2023_EPL_Manchester City       85.0   17.0   4.0    7.0
#
#                                                 PPM   onG  onGA  On-Off
# unique_id
# Ederson_2022-2023_EPL_Manchester City          2.34  89.0  32.0    0.30
# Rodri_2022-2023_EPL_Manchester City            2.39  83.0  26.0    1.06
# Erling Haaland_2022-2023_EPL_Manchester City   2.37  84.0  26.0    1.47
# Kevin De Bruyne_2022-2023_EPL_Manchester City  2.31  69.0  23.0    0.37
# İlkay Gündoğan_2022-2023_EPL_Manchester City   2.39  71.0  20.0    1.11
#
# [5 rows x 149 columns]

# %%
# store squad opponent statistics
squad_opponent_stats = df[(df['Player'] == 'Squad Total') | (df['Player'] == 'Opponent Total') ] 
squad_opponent_stats = squad_opponent_stats.reset_index().drop(columns='unique_id').rename(columns={'Player': 'Status'})
squad_opponent_stats.to_csv('../data/fbref/squad_opponent_stats.csv',index=True)

# store player statistics
player_stats = df[(df['Player'] != 'Squad Total') & (df['Player'] != 'Opponent Total')]
player_stats.to_csv('../data/fbref/player_stats.csv',index=True)
